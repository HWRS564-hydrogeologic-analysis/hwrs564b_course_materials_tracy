# %%
def count_days_in_month(month):
    """When given month (1-12) return days in month"""
    if (month > 12) or (month<1):
        print('choose a number between 1 and 12')
    else:
        days = [31, 28, 31, 30, 31, 30, 31, 31, 30, 31, 30, 31]
        return days[month - 1]

# %%
count_days_in_month(13)
# Out:
# choose a number between 1 and 12

# %%
month=input('Please enter a month as an integer between 1 and 12: ')
leap_year=True
def convert_month_to_days(month):
    if month in ["Jan", "Mar," "May", "Jul", "Aug", "Oct", "Dec"]:
        return 31
    elif month in ["Apr", "Jun," "Sep", "Nov"]:
        return 30
    elif month in ["Feb"]:
        if(leap_year):
            return 29
        else:
            return 28
        
print(f'{month}, {leap_year} has {convert_month_to_days(month, leap_year=True)} days')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[16], line 14
#      11         else:
#      12             return 28
# ---> 14 print(f'{month}, {leap_year} has {convert_month_to_days(month, leap_year=True)} days')
#
# TypeError: convert_month_to_days() got an unexpected keyword argument 'leap_year'
